# %%
import pandas

# %%
ls
# Out:
# b1.csv  c2.csv  m4.csv  p2.csv    pcb3.csv        users.csv
# c1.csv  m3.csv  p1.csv  pcb2.csv  Untitled.ipynb

# %%
p1 = pandas.read_csv('p1.csv')
c1 = pandas.read_csv('c1.csv')
b1 = pandas.read_csv('b1.csv')



#---------------------------------------------------------


#m2


#---------------------------------------------------------


p2 = pandas.read_csv('p2.csv')
c2 = pandas.read_csv('c2.csv')

pcb2 = pandas.read_csv('pcb2.csv')


#---------------------------------------------------------

m3 = pandas.read_csv('m3.csv')


#--------------------------------------------------


pcb3 = pandas.read_csv('pcb3.csv')


#--------------------------------------------------

m4 = pandas.read_csv('m4.csv')

#--------------------------------------------------    


user = pandas.read_csv('users.csv')

# %%
p1[]
# Out:
#             Last name         First name                      Email address  \
# 0                Alva             Nikhil              mnikhilalva@gmail.com
# 1               Uppar            Chaitra               gayatriu34@gmail.com
# 2              Angadi            Prathik              prathik2027@gmail.com
# 3            Garapati     Bharath kalyan       lakshmi.cherry2011@gmail.com
# 4                   V             Rajath              rajathv2352@gmail.com
# ...               ...                ...                                ...
# 1104       Sathrasala          Harshitha  harshithasathrasala1986@gmail.com
# 1105            Adnur      Harshavardhan              sspsaiti531@gmail.com
# 1106         Halasagi  Prajwal Shivanand             ravihalasagi@yahoo.com
# 1107             nair            adithya         saiadithya251115@gmail.com
# 1108  Overall average                NaN                                NaN
#
# ...

# %%
sum(math['Grade/60.00'])
# Out:
# 10563.45

# %%
ls
# Out:
# 'day 1 b2 .csv'  'day 3 p2.csv'                  'day 6 math.csv'   Users.csv
# 'day 1 c2.csv'   'day 3 pcb (bio students).csv'   moodle/
# 'day 1 p1.csv'   'day 4 math 3.csv'               moodle.tar.gz
# 'day 3 c2.csv'   'day 5 pcb.csv'                  Untitled.ipynb
